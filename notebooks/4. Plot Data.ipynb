# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
BASE_DIR = os.getcwd()
DATA_DIR = os.path.join(BASE_DIR, 'Data')
file_path = os.path.join(DATA_DIR, 'dataset.csv')

# %%
dataset = pd.read_csv(file_path, index_col='Unnamed: 0')
dataset.columns
# Out:
# Index(['Tech House', 'Techno (Peak Time / Driving)', 'Electro House',
#        'Progressive House', 'Minimal / Deep Tech', 'House',
#        'Techno (Raw / Deep / Hypnotic)', 'Deep House', 'Electronica', 'Trance',
#        'Funky / Groove / Jackin' House', 'Progressive',
#        'Melodic House & Techno', 'Indie Dance', 'Breaks / Breakbeat / UK Bass',
#        'Drum & Bass', 'Dubstep', 'Psy-Trance', 'Future House',
#        'Dance / Electro Pop', 'Big Room', 'Trap / Wave', 'Afro House',
#        'Organic House / Downtempo', 'Bass House', 'Nu Disco / Disco',
#        'Hard Dance / Hardcore', '140 / Deep Dubstep / Grime'],
#       dtype='object')

# %%
dataset.tail()
# Out:
#       Tech House  Techno (Peak Time / Driving)  Electro House  \
# 2017        1260                          1253             63
# 2018         929                          1419             72
# 2019         992                          1545             29
# 2020        1106                          1323             21
# 2021        1099                           958             45
#
#       Progressive House  Minimal / Deep Tech  House  \
# 2017                352                  259    550
# 2018                529                  452    569
# 2019                512                  632    442
# 2020                373                  756    658
# 2021                322                  451    654
#
#       Techno (Raw / Deep / Hypnotic)  Deep House  Electronica  Trance  ...  \
# 2017                             143         582          147     156  ...
# 2018                             172         364          143     403  ...
# ...

# %%
plt.figure(figsize=(16,8))
sns.relplot(data=dataset, kind='line')

# %%
# plt.figure(figsize=(16,8))
# sns.lineplot(data=dataset['Techno (Peak Time / Driving)'], label='Techno')
# sns.lineplot(data=dataset['Tech House'], label='Tech House')

# %%
# dataset_2 = dataset.reset_index().rename(columns={'index': 'Year'})

# %%
techno = dataset.loc[:, ['Techno (Peak Time / Driving)', 'Minimal / Deep Tech', 'Techno (Raw / Deep / Hypnotic)', 'Melodic House & Techno']]
house = dataset.loc[:, ['House', 'Deep House', 'Tech House', 'Future House', 'Electro House', 'Progressive House', 'Afro House', 'Bass House']]

# %% [markdown]
# ## 1. Using Seaborn

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=house)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=techno)
# Out:
# <AxesSubplot:>

# %%
house_pop = dataset.loc[:, ['House', 'Deep House', 'Tech House', 'Electro House']]
plt.figure(figsize=(16,8))
sns.lineplot(data=house_pop)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=dataset['Techno (Peak Time / Driving)'])
sns.lineplot(data=dataset['Tech House'])
# Out:
# <AxesSubplot:ylabel='Techno (Peak Time / Driving)'>

# %% [markdown]
# ## 2. Using pandas.plot() method

# %%
house_pop.plot(figsize=(16,8))
plt.xlabel("Year", labelpad=15)
plt.ylabel("Number of occurrences on Beatport Charts", labelpad=15)
plt.title("House Subgenres Popularity")
# Out:
# Text(0.5, 1.0, 'House Subgenres Popularity')
