# %%
import os
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
BASE_DIR = os.getcwd()
DATA_DIR = os.path.join(BASE_DIR, 'Data')
TEMP_DIR = os.path.join(BASE_DIR, 'Temp')

# %%
def links(url):
    """Return a list of links."""
    base_url = 'https://www.beatport.com'
    r = requests.get(url)
    if r.status_code not in range(200,299):
        return False
    soup = BeautifulSoup(r.content, 'html.parser')
    links = []
    for link in soup.select('li.bucket-item'):
        link = link.find('a').get('href')
        links.append(base_url + link)
    return links

def chart(link): 
    """Extract data from a single link, return Pandas Series."""
    headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36"}
    try:
        r = requests.get(link, headers)
        soup = BeautifulSoup(r.content, 'html.parser')
        date = soup.find('span', class_='value').string
        chart = []
        for genre in soup.find_all('p', class_='buk-track-labels')[1:]:
            genre = genre.find('a').string
            item = genre
            chart.append(item)
        series = pd.Series(chart, dtype=str, name=date)
        return series
    except AttributeError:
        print('Invalid.')
        
def run(url):
    """Run the scraper for all links in the list and return Pandas DataFrame."""
    my_links = links(url)
    my_links.pop(-1)
    temp = [chart(link) for link in my_links]
    data = pd.concat(temp, axis=1)
    print('Done.')
    return data

# %%
url = 'https://www.beatport.com/artist/roger-m/94966/charts'
df = run(url)
# Out:
# Done.

# %%
df
# Out:
#              2021-08-16                  2021-07-05               2021-06-08  \
# 0      Perfecto Records       Black Hole Recordings                Incorrect
# 1            Anjunadeep            Perfecto Records               STEREOHYPE
# 2        Pryda Presents                Sink or Swim  Farris Wheel Recordings
# 3     CircoLoco Records             Enormous Chills              Rose Avenue
# 4                  EDMA                   The Vault           Oddity Records
# 5      DAYS like NIGHTS                 Anjunabeats                     FSOE
# 6            Hell Beach               SPINNIN' DEEP                     EDMA
# 7                 Ultra                 Dog Triumph           Another Rhythm
# 8       The Myth of NYX  Armada Electronic Elements               ZYX TRANCE
# 9  Space Motion Records                Armada Music         Tactical Records
#
#              2021-05-06            2021-03-28                    2021-02-28  \
# 0          Armada Music                  EDMA                          EDMA
# 1  Caballero Recordings         SPINNIN' DEEP  Ministry of Sound Recordings
# 2     MASTERMIX RECORDS     Afterlife Records                 Tiger Records
# 3      Crosstown Rebels          Savage Disco                  Armada Music
# 4          Lost & Found                  EDMA                Perfecto House
# 5       Repopulate Mars        Pryda Presents                Generation HEX
# 6    Black Book Records  Flashover Recordings                    Anjunadeep
# 7        Pryda Presents    A state of Trance                    Juicy Traxx
# 8            Hell Beach          Sink or Swim             Afterlife Records
# 9      Crosstown Rebels       Timeless Moment                   Anjunabeats
#
#          2021-01-26            2021-01-02           2020-12-17  \
# 0    Perfecto House          Armada Music             D4 D4NCE
# 1              EDMA              Defected     Perfecto Records
# 2            Virgin                  EDMA             Defected
# 3       Juicy Traxx       Armind (Armada)    RCA Records Label
# 4     DOORN RECORDS  Flashover Recordings              ISO LAT
# 5    Pryda Presents                  EDMA  Glasgow Underground
# 6  Big Beat Records            Anjunadeep         METAPHYSICAL
# 7              EDMA               Siamese  Glasgow Underground
# 8      Arcane Music   Parlophone (France)             Toolroom
# 9              EDMA                  FFRR     Fishtone Records
#
#              2020-10-30  ...                2020-06-12          2020-05-08  \
# 0                  EDMA  ...          PinkStar Records    SPINNIN' RECORDS
# 1              AFTR:HRS  ...              Armada Music                EDMA
# 2       Musical Freedom  ...                     Ultra   Nativa Recordings
# 3        Generation HEX  ...         RCA Records Label        Idol Records
# 4   Groovy Firehorse 66  ...            Armada Subjekt    SPINNIN' RECORDS
# 5      Tactical Records  ...                      EDMA    Tactical Records
# 6        Enormous Tunes  ...          Fishtone Records  A state of Trance
# 7      SPINNIN' RECORDS  ...                      EDMA    SPINNIN' RECORDS
# 8      SPINNIN' RECORDS  ...  Trance All-Stars Records                EDMA
# 9  Caballero Recordings  ...                       NaN                 NaN
#
#              2020-03-26                    2019-11-17         2019-10-11  \
# 0                  EDMA             PornoStar Records      Sirup Records
# 1   Armada Music Albums               Repopulate Mars      ABODE Records
# 2        Kontor Records                      Drumcode        Cr2 Records
# 3      Tactical Records                   Cr2 Records               EDMA
# 4                HouseU  Ministry of Sound Recordings            Low:Res
# 5      Tactical Records           Glasgow Underground               DFTD
# 6           Whore House                   Embassy One           Defected
# 7  Darksound Recordings                      Diynamic  PornoStar Records
# 8             Different  Ministry of Sound Recordings           Defected
# 9                  EDMA               Capitol Records        Juicy Music
#
#             2019-09-14          2019-08-06        2019-07-08  \
# 0  Armada Music Albums  Get Physical Music              EDMA
# 1    PornoStar Records     New State Music  Big Beat Records
# 2    PornoStar Records     Ammo Recordings     SPINNIN' DEEP
# 3     Infectious Music          Ninja Tune      Lost Records
# 4   Get Physical Music            Defected   Catch & Release
# 5       Axtone Records          Club Sweat              EDMA
# 6            DIRTYBIRD          Anjunadeep      Maya Records
# 7     Next-Gen-Records       SPINNIN' DEEP    Votiva Records
# 8    RCA Records Label   Afterlife Records           Stashed
# 9                 EDMA            SOLOTOKO               NaN
#
#             2019-06-22                    2019-05-14
# 0                Wired               Catch & Release
# 1      Catch & Release                         Wired
# 2                 EDMA                 Sirup Records
# 3              Stashed                    Club Sweat
# 4                 EDMA  Ministry of Sound Recordings
# 5          Sub Society                      Defected
# 6        Diper Records                    Ninja Tune
# 7  Renaissance Records              Big Beat Records
# 8    Big Top Amsterdam                       Selador
# 9                 EDMA                           NaN
#
# [10 rows x 24 columns]

# %%
df.to_csv(os.path.join(DATA_DIR, 'roger.csv'))
